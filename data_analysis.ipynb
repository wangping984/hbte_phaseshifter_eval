# %%
import skrf as rf

reference = rf.Network('data_20220920/ref.s2p')
deg1 = rf.Network('data_20220920/deg1.s2p')

reference.plot_s_deg(m=1,n=0)

# %%
reference.s21.plot_s_deg()

# %%
diff = deg1.s21 / reference.s21
diff.plot_s_db()

# %%
diff.plot_s_deg()

# %%
deg0 = rf.Network('data_20220920/A1B1_deg100.s2p')
deg1 = rf.Network('data_20220920/A1B1_deg101.s2p')
deg2 = rf.Network('data_20220920/A1B1_deg102.s2p')
diff = deg1.s21 / deg0.s21
diff.plot_s_deg()

# %%
diff = deg2.s21 / deg1.s21
diff.plot_s_deg()

# %%
deg0 = rf.Network('data_20220920/A1B1_deg2.s2p')
deg1 = rf.Network('data_20220920/A1B1_deg3.s2p')
diff = deg1.s21 / deg0.s21
diff.plot_s_deg()

# %%
deg0 = rf.Network('data_20220920/A1B1_mag30.5.s2p')
deg1 = rf.Network('data_20220920/A1B1_mag31.0.s2p')
diff = deg1.s21 / deg0.s21
diff.plot_s_db()
